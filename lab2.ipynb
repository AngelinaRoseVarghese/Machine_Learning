# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error,r2_score

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"

df = pd.read_csv(url)

df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
x = df[['displacement']]
y = df['mpg']
print("Missing values in ",x.isnull().sum())
print("Missing values in mpg:",y.isnull().sum())
# Out:
# Missing values in  displacement    0
# dtype: int64
# Missing values in mpg: 0

# %%
data = df[['displacement','mpg']].dropna()
x = data[['displacement']]
y = data['mpg']
print("Feature:")
print(x.head())
print("\nTarget:")
print(y.head())
# Out:
# Feature:
#    displacement
# 0         307.0
# 1         350.0
# 2         318.0
# 3         304.0
# 4         302.0
#
# Target:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %%
plt.figure(figsize=(8,5))
plt.scatter(x,y)
plt.xlabel("Engine Displacement")
plt.ylabel("Miles Per Gallon (MPG)")
plt.title("Engine Displacement vs MPG")
plt.grid(True)
plt.show()

# %%
x_train,x_test, y_train,y_test =train_test_split(
    x,
    y,
    test_size=0.2,
    random_state = 42
)
print("Training samples: ",len(x_train))
print("Testing samples: ",len(x_test))
# Out:
# Training samples:  318
# Testing samples:  80

# %%
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
y_pred_linear = linear_model.predict(x_test)

# %%
mse_linear = mean_squared_error(y_test,y_pred_linear)
r2_linear = r2_score(y_test,y_pred_linear)
print("Linear Regression Results")
print("--------------------------")
print("MSE:",mse_linear)
print("R-squared:",r2_linear)
# Out:
# Linear Regression Results
# --------------------------
# MSE: 18.102543998358946
# R-squared: 0.6633114869465595

# %%
results=[]
polynomial_model = {}
results.append({
    'Model':'Linear Regression',
    'Degree':1,
    'MSE':mse_linear,
    'R-squared':r2_linear
})
for degree in range(2,6):
    poly = PolynomialFeatures(degree=degree)
    x_train_poly = poly.fit_transform(x_train)
    x_test_poly = poly.transfrom(x_test)
    poly_model = LinearRegression()
    poly_model.fit(x_train_poly,y_train)
    y_pred
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 12
#      10 poly = PolynomialFeatures(degree=degree)
#      11 x_train_poly = poly.fit_transform(x_train)
# ---> 12 x_test_poly = poly.transfrom(x_test)
#      13 poly_model = LinearRegression()
#      14 poly_model.fit(x_train_poly,y_tarin)
#
# AttributeError: 'PolynomialFeatures' object has no attribute 'transfrom'
